# %%
#import important libraries
import pandas as pd
import numpy as np
import matplotlib as mtb
import seaborn as sns

# %%
#read the dataset
file_path= r"C:\Users\91835\AB_NYC_2019.csv"
abc=pd.read_csv(file_path)
abc
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#find count of missing values
missing_values=abc.isnull().sum()
print(missing_values)
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#drop all null values
abc_cleaned=abc.dropna()

# %%
#convert argument datatype to the datatype of column
abc_cleaned['price']=pd.to_numeric(abc_cleaned['price'])
abc_cleaned['last_review']=pd.to_datetime(abc_cleaned['last_review'])
abc_cleaned['reviewss_per_month']=pd.to_numeric(abc_cleaned['reviews_per_month'])
abc_cleaned['minimum_nights']=pd.to_numeric(abc_cleaned['minimum_nights'])
abc_cleaned['calculated_host_listings_count']=pd.to_numeric(abc_cleaned['calculated_host_listings_count'])
abc_cleaned['availability_365']=pd.to_numeric(abc_cleaned['availability_365'])
abc_cleaned['name']=abc_cleaned['name'].astype(str)
# Out:
# C:\Users\91835\AppData\Local\Temp\ipykernel_14768\1882139361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abc_cleaned['price']=pd.to_numeric(abc_cleaned['price'])
# C:\Users\91835\AppData\Local\Temp\ipykernel_14768\1882139361.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abc_cleaned['last_review']=pd.to_datetime(abc_cleaned['last_review'])
# C:\Users\91835\AppData\Local\Temp\ipykernel_14768\1882139361.py:3: SettingWithCopyWarning:
# ...

# %%
#cleaned dataset with no null values
abc_cleaned
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %%
#forward fill method to fill missing values
abc_cleaned['name'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\91835\AppData\Local\Temp\ipykernel_14768\962708817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abc_cleaned['name'].fillna(method='ffill', inplace=True)

# %%
#finding missing values in cleaned dataset
missing_values=abc_cleaned.isnull().sum()
print(missing_values)
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# reviewss_per_month                0
# dtype: int64

# %%
#drop all duplicates from the dataset
duplicates1=abc_cleaned.drop_duplicates()

# %%
#cleaned dataset with duplicates and null values
duplicates1
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...
